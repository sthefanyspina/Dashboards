# %%
import pandas as pd

# %%
df = pd.read_csv('players.csv')

# %%
df.head()
# Out:
#           id   birthdate              birthplace  career_ast  career_fg  \
# 0  abdelal01  1968-06-24            Cairo, Egypt         0.3       50.2
# 1  abdulza01  1946-04-07      Brooklyn, New York         1.2       42.8
# 2  abdulka01  1947-04-16      New York, New York         3.6       55.9
# 3  abdulma02  1969-03-09   Gulfport, Mississippi         3.5       44.2
# 4  abdulta01  1974-11-03  Maisons Alfort, France         1.1       41.7
#
#    career_fg3  career_ft  career_g  career_per  career_pts  ...    draft_pick  \
# 0         0.0       70.1       256        13.0         5.7  ...  25th overall
# 1         NaN       72.8       505        15.1         9.0  ...   5th overall
# 2         5.6       72.1      1560        24.6        24.6  ...   1st overall
# 3        35.4       90.5       586        15.4        14.6  ...   3rd overall
# 4        23.7       70.3       236        11.4         7.8  ...  11th overall
#
#    draft_round              draft_team draft_year height  \
# ...

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#       id  birthdate  birthplace  career_ast  career_fg  career_fg3  career_ft  \
# 0  False      False       False       False      False       False      False
# 1  False      False       False       False      False        True      False
# 2  False      False       False       False      False       False      False
# 3  False      False       False       False      False       False      False
# 4  False      False       False       False      False       False      False
#
#    career_g  career_per  career_pts  ...  draft_pick  draft_round  draft_team  \
# 0     False       False       False  ...       False        False       False
# 1     False       False       False  ...       False        False       False
# 2     False       False       False  ...       False        False       False
# 3     False       False       False  ...       False        False       False
# 4     False       False       False  ...       False        False       False
#
# ...

# %%
df.dropna()
# Out:
#              id   birthdate              birthplace  career_ast  career_fg  \
# 0     abdelal01  1968-06-24            Cairo, Egypt         0.3       50.2
# 2     abdulka01  1947-04-16      New York, New York         3.6       55.9
# 3     abdulma02  1969-03-09   Gulfport, Mississippi         3.5       44.2
# 4     abdulta01  1974-11-03  Maisons Alfort, France         1.1       41.7
# 5     abdursh01  1976-12-11       Marietta, Georgia         2.5       47.2
# ...         ...         ...                     ...         ...        ...
# 4661  youngth01  1988-06-21  New Orleans, Louisiana         1.7       50.1
# 4663  youngtr01  1998-09-19          Lubbock, Texas         8.1       41.8
# 4667  zelleco01  1992-10-05     Washington, Indiana         1.4       51.1
# 4672  zellety01  1990-01-17     Visalia, California         0.9       50.9
# 4676  zidekge01  1973-08-02    Zlin, Czech Republic         0.2       40.8
#
# ...

# %%
print(df.dtypes)
# Out:
# id              object
# birthdate       object
# birthplace      object
# career_ast     float64
# career_fg      float64
# career_fg3     float64
# career_ft      float64
# career_g         int64
# career_per     float64
# career_pts     float64
# career_trb     float64
# career_ws      float64
# career_efg     float64
# college         object
# draft_pick      object
# draft_round     object
# draft_team      object
# draft_year      object
# height          object
# highschool      object
# name            object
# position        object
# shoots          object
# weight          object
# dtype: object

# %%
df.to_csv("players2.csv", index=False)
